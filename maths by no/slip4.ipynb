# %%
###Q1

# %%
#1.
from sympy import*

# %%
tuple1=(5,-3, 0, 1, 6,-6, 2)
##descending
tuple(sorted(tuple1,reverse=True))
# Out:
# (6, 5, 2, 1, 0, -3, -6)

# %%
##ascending
tuple(sorted(tuple1))
# Out:
# (-6, -3, 0, 1, 2, 5, 6)

# %%
#3.

# %%
for num in range(1,21):
    while num%2!=0:
        print(num,num**2)
        break
# Out:
# 1 1
# 3 9
# 5 25
# 7 49
# 9 81
# 11 121
# 13 169
# 15 225
# 17 289
# 19 361

# %%
##Q2

# %%
number = 0
type(number)
# Out:
# int

# %%
type(31.25)
# Out:
# float

# %%
type(8 + 4j)
# Out:
# complex

# %%
Mathematics = 0
type(Mathematics)
# Out:
# int

# %%
type(49)
# Out:
# int

# %%
##Q3
from sympy import*

# %%
A=Matrix([[1,0,5],[2,1,6],[3,4,0]])

# %%
A.det()
# Out:
# 1

# %%
B=Matrix([[2,5],[-1,4]])

# %%
B.det()
# Out:
# 13
